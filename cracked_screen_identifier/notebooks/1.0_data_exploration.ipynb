# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
label  = pd.read_csv("data/interim/labels.csv")
label
# Out:
#                image    label
# 0        image_0.jpg  cracked
# 1        image_1.jpg  cracked
# 2        image_2.jpg  cracked
# 3        image_3.jpg  cracked
# 4        image_4.jpg  cracked
# ...              ...      ...
# 1017  image_1017.jpg  perfect
# 1018  image_1018.jpg  perfect
# 1019  image_1019.jpg  perfect
# 1020  image_1020.jpg  perfect
# 1021  image_1021.jpg  perfect
#
# [1022 rows x 2 columns]

# %%
sns.countplot(data=label, x=label['label'], width=0.35)
plt.show()
plt.

# %%
cd ..
# Out:
# /Users/olumide/Documents/Self Improvement - ML/MLapps/ML_EndtoEnd_Projects/cracked_screen_identifier

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob

# Path to the folder containing your images
image_folder = "cracked_screen_identifier/data/Archive/interim"

# Search for jpg files in the folder
image_filenames = glob.glob(f"{image_folder}/*.jpg")

# Shuffle the list of image filenames
np.random.shuffle(image_filenames)

# Create a figure and a grid of subplots
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(10, 8))

# Flatten the axes array to make it easier to iterate
axes = axes.flatten()

for i, ax in enumerate(axes):
    if i < len(image_filenames):
        image = plt.imread(image_filenames[i])
        ax.imshow(image)
        ax.axis('off')
    else:
        ax.axis('off')  # Turn off unused subplots

plt.tight_layout()
plt.show()

# %%
train_label =  pd.read_csv("data/processed/train/label.csv")
sns.countplot(data=train_label, x=train_label['label'])
plt.show()

# %%
val_label =  pd.read_csv("data/processed/val/label.csv")
sns.countplot(data=val_label, x=val_label['label'])
plt.show()

# %%
images = os.listdir("data/interim")[50]
